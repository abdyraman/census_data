# %%
import pandas as pd
import numpy as np

# %%
file_path = "CanadaCensus.csv"

# Read the CSV file with 'utf-8' encoding and handle errors with 'latin-1'
try:
    df = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding='latin-1')

# %%
columns_to_keep = ['GEO_NAME', 'CHARACTERISTIC_NAME','C1_COUNT_TOTAL', 'C2_COUNT_MEN+', 'C3_COUNT_WOMEN+']

# %%
df =df[columns_to_keep]

# %%
df.tail(25)
# Out:
#       GEO_NAME                                CHARACTERISTIC_NAME  \
# 36809  Nunavut                                     Public transit
# 36810  Nunavut                                             Walked
# 36811  Nunavut                                            Bicycle
# 36812  Nunavut                                       Other method
# 36813  Nunavut  Total - Commuting duration for the employed la...
# 36814  Nunavut                               Less than 15 minutes
# 36815  Nunavut                                   15 to 29 minutes
# 36816  Nunavut                                   30 to 44 minutes
# 36817  Nunavut                                   45 to 59 minutes
# 36818  Nunavut                                60 minutes and over
# 36819  Nunavut  Total - Time leaving for work for the employed...
# 36820  Nunavut                       Between 5 a.m. and 5:59 a.m.
# 36821  Nunavut                       Between 6 a.m. and 6:59 a.m.
# 36822  Nunavut                       Between 7 a.m. and 7:59 a.m.
# 36823  Nunavut                       Between 8 a.m. and 8:59 a.m.
# 36824  Nunavut                      Between 9 a.m. and 11:59 a.m.
# 36825  Nunavut                      Between 12 p.m. and 4:59 a.m.
# 36826  Nunavut  Total - Eligibility for instruction in the min...
# 36827  Nunavut    Children eligible for instruction in the min...
# 36828  Nunavut    Children not eligible for instruction in the...
# 36829  Nunavut  Total - Eligibility and instruction in the min...
# 36830  Nunavut    Children eligible for instruction in the min...
# 36831  Nunavut      Eligible children who have been instructed...
# 36832  Nunavut      Eligible children who have not been instru...
# 36833  Nunavut    Children not eligible for instruction in the...
#
#        C1_COUNT_TOTAL  C2_COUNT_MEN+  C3_COUNT_WOMEN+
# 36809           100.0           55.0             45.0
# 36810          3970.0         1765.0           2200.0
# 36811            30.0           15.0             10.0
# 36812          1215.0          590.0            625.0
# 36813         11075.0         5490.0           5585.0
# 36814          9670.0         4780.0           4895.0
# 36815          1095.0          515.0            580.0
# 36816           135.0           75.0             65.0
# 36817            40.0           20.0             10.0
# 36818           130.0           90.0             30.0
# 36819         11075.0         5490.0           5585.0
# 36820           190.0          160.0             40.0
# 36821           515.0          395.0            120.0
# 36822          1770.0         1120.0            650.0
# 36823          6305.0         2765.0           3530.0
# 36824          1225.0          565.0            660.0
# 36825          1065.0          485.0            580.0
# 36826         14180.0         7205.0           6980.0
# 36827           535.0          270.0            260.0
# 36828         13645.0         6935.0           6715.0
# 36829          9500.0         4745.0           4755.0
# 36830           360.0          185.0            175.0
# 36831           215.0          100.0            115.0
# 36832           140.0           80.0             60.0
# 36833          9140.0         4555.0           4585.0

# %%
df['Level'] = (df['CHARACTERISTIC_NAME'].apply(len)-df['CHARACTERISTIC_NAME'].str.strip().apply(len))/2

# %%
max_level = int(df['Level'].max())

# %%
level_val=df['Level'].unique()

# %%
level_list =[]

# %%
level_list = ["Lvl-" + str(i) for i in range(0, max_level + 1)]

# %%
level_list
# Out:
# ['Lvl-0',
#  'Lvl-1',
#  'Lvl-2',
#  'Lvl-3',
#  'Lvl-4',
#  'Lvl-5',
#  'Lvl-6',
#  'Lvl-7',
#  'Lvl-8']

# %%
for column_name in level_list:
        df[column_name] = column_name

# %%
for column_name in level_list:
        df[column_name] = np.nan

# %%
df
# Out:
#       GEO_NAME                                CHARACTERISTIC_NAME  \
# 0       Canada                                   Population, 2021
# 1       Canada                                   Population, 2016
# 2       Canada         Population percentage change, 2016 to 2021
# 3       Canada                            Total private dwellings
# 4       Canada      Private dwellings occupied by usual residents
# ...        ...                                                ...
# 36829  Nunavut  Total - Eligibility and instruction in the min...
# 36830  Nunavut    Children eligible for instruction in the min...
# 36831  Nunavut      Eligible children who have been instructed...
# 36832  Nunavut      Eligible children who have not been instru...
# 36833  Nunavut    Children not eligible for instruction in the...
#
#        C1_COUNT_TOTAL  C2_COUNT_MEN+  C3_COUNT_WOMEN+  Level  Lvl-0  Lvl-1  \
# 0          36991981.0            NaN              NaN    0.0    NaN    NaN
# 1          35151728.0            NaN              NaN    0.0    NaN    NaN
# 2                 5.2            NaN              NaN    0.0    NaN    NaN
# 3          16284235.0            NaN              NaN    0.0    NaN    NaN
# 4          14978941.0            NaN              NaN    0.0    NaN    NaN
# ...               ...            ...              ...    ...    ...    ...
# 36829          9500.0         4745.0           4755.0    0.0    NaN    NaN
# 36830           360.0          185.0            175.0    1.0    NaN    NaN
# 36831           215.0          100.0            115.0    2.0    NaN    NaN
# 36832           140.0           80.0             60.0    2.0    NaN    NaN
# 36833          9140.0         4555.0           4585.0    1.0    NaN    NaN
#
#        Lvl-2  Lvl-3  Lvl-4  Lvl-5  Lvl-6  Lvl-7  Lvl-8
# 0        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...      ...    ...    ...    ...    ...    ...    ...
# 36829    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 36830    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 36831    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 36832    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 36833    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [36834 rows x 15 columns]

# %%
df_play = df.copy()

# %%
# Iterate through the DataFrame rows
for index, row in df_play.iterrows():

    for level_column in level_list:
            if row['Level'] == int(level_column.split('-')[1]):
                characteristic_name = row['CHARACTERISTIC_NAME'].strip()
                df_play.at[index, level_column] = characteristic_name

# %%
df_play.tail(50)
# Out:
#       GEO_NAME                                CHARACTERISTIC_NAME  \
# 36784  Nunavut                                               None
# 36785  Nunavut                                            English
# 36786  Nunavut                                             French
# 36787  Nunavut                              Non-official language
# 36788  Nunavut                                         Indigenous
# 36789  Nunavut                                     Non-Indigenous
# 36790  Nunavut                                 English and French
# 36791  Nunavut               English and non-official language(s)
# 36792  Nunavut                French and non-official language(s)
# 36793  Nunavut       English, French and non-official language(s)
# 36794  Nunavut                    Multiple non-official languages
# 36795  Nunavut  Total - Place of work status for the employed ...
# 36796  Nunavut                                     Worked at home
# 36797  Nunavut                              Worked outside Canada
# 36798  Nunavut                         No fixed workplace address
# 36799  Nunavut                                Usual place of work
# 36800  Nunavut  Total - Commuting destination for the employed...
# 36801  Nunavut    Commute within census subdivision (CSD) of r...
# 36802  Nunavut    Commute to a different census subdivision (C...
# 36803  Nunavut    Commute to a different census subdivision (C...
# 36804  Nunavut       Commute to a different province or territory
# 36805  Nunavut  Total - Main mode of commuting for the employe...
# 36806  Nunavut                                  Car, truck or van
# 36807  Nunavut                    Car, truck or van - as a driver
# 36808  Nunavut                 Car, truck or van - as a passenger
# 36809  Nunavut                                     Public transit
# 36810  Nunavut                                             Walked
# 36811  Nunavut                                            Bicycle
# 36812  Nunavut                                       Other method
# 36813  Nunavut  Total - Commuting duration for the employed la...
# 36814  Nunavut                               Less than 15 minutes
# 36815  Nunavut                                   15 to 29 minutes
# 36816  Nunavut                                   30 to 44 minutes
# 36817  Nunavut                                   45 to 59 minutes
# 36818  Nunavut                                60 minutes and over
# 36819  Nunavut  Total - Time leaving for work for the employed...
# 36820  Nunavut                       Between 5 a.m. and 5:59 a.m.
# 36821  Nunavut                       Between 6 a.m. and 6:59 a.m.
# 36822  Nunavut                       Between 7 a.m. and 7:59 a.m.
# 36823  Nunavut                       Between 8 a.m. and 8:59 a.m.
# 36824  Nunavut                      Between 9 a.m. and 11:59 a.m.
# 36825  Nunavut                      Between 12 p.m. and 4:59 a.m.
# 36826  Nunavut  Total - Eligibility for instruction in the min...
# 36827  Nunavut    Children eligible for instruction in the min...
# 36828  Nunavut    Children not eligible for instruction in the...
# 36829  Nunavut  Total - Eligibility and instruction in the min...
# 36830  Nunavut    Children eligible for instruction in the min...
# 36831  Nunavut      Eligible children who have been instructed...
# 36832  Nunavut      Eligible children who have not been instru...
# 36833  Nunavut    Children not eligible for instruction in the...
#
#        C1_COUNT_TOTAL  C2_COUNT_MEN+  C3_COUNT_WOMEN+  Level  \
# 36784         10900.0         5585.0           5310.0    1.0
# 36785          1995.0          940.0           1055.0    1.0
# 36786           220.0          135.0             85.0    1.0
# 36787          2025.0          950.0           1075.0    1.0
# 36788          2020.0          950.0           1075.0    2.0
# 36789             0.0            0.0              0.0    2.0
# 36790             0.0            0.0              0.0    1.0
# 36791            10.0            0.0              0.0    1.0
# 36792            30.0            0.0             15.0    1.0
# 36793             0.0            0.0              0.0    1.0
# 36794            10.0           10.0              0.0    1.0
# 36795         11945.0         5910.0           6035.0    0.0
# 36796           870.0          425.0            450.0    1.0
# 36797            10.0            0.0              0.0    1.0
# 36798          1205.0          875.0            330.0    1.0
# 36799          9870.0         4610.0           5255.0    1.0
# 36800          9870.0         4615.0           5255.0    0.0
# 36801          9155.0         4260.0           4895.0    1.0
# 36802           520.0          260.0            260.0    1.0
# 36803           145.0           70.0             75.0    1.0
# 36804            50.0           25.0             25.0    1.0
# 36805         11075.0         5490.0           5585.0    0.0
# 36806          5760.0         3060.0           2700.0    1.0
# 36807          4155.0         2325.0           1830.0    2.0
# 36808          1610.0          730.0            875.0    2.0
# 36809           100.0           55.0             45.0    1.0
# 36810          3970.0         1765.0           2200.0    1.0
# 36811            30.0           15.0             10.0    1.0
# 36812          1215.0          590.0            625.0    1.0
# 36813         11075.0         5490.0           5585.0    0.0
# 36814          9670.0         4780.0           4895.0    1.0
# 36815          1095.0          515.0            580.0    1.0
# 36816           135.0           75.0             65.0    1.0
# 36817            40.0           20.0             10.0    1.0
# 36818           130.0           90.0             30.0    1.0
# 36819         11075.0         5490.0           5585.0    0.0
# 36820           190.0          160.0             40.0    1.0
# 36821           515.0          395.0            120.0    1.0
# 36822          1770.0         1120.0            650.0    1.0
# 36823          6305.0         2765.0           3530.0    1.0
# 36824          1225.0          565.0            660.0    1.0
# 36825          1065.0          485.0            580.0    1.0
# 36826         14180.0         7205.0           6980.0    0.0
# 36827           535.0          270.0            260.0    1.0
# 36828         13645.0         6935.0           6715.0    1.0
# 36829          9500.0         4745.0           4755.0    0.0
# 36830           360.0          185.0            175.0    1.0
# 36831           215.0          100.0            115.0    2.0
# 36832           140.0           80.0             60.0    2.0
# 36833          9140.0         4555.0           4585.0    1.0
#
#                                                    Lvl-0  \
# 36784                                                NaN
# 36785                                                NaN
# 36786                                                NaN
# 36787                                                NaN
# 36788                                                NaN
# 36789                                                NaN
# 36790                                                NaN
# 36791                                                NaN
# 36792                                                NaN
# 36793                                                NaN
# 36794                                                NaN
# 36795  Total - Place of work status for the employed ...
# 36796                                                NaN
# 36797                                                NaN
# 36798                                                NaN
# 36799                                                NaN
# 36800  Total - Commuting destination for the employed...
# 36801                                                NaN
# 36802                                                NaN
# 36803                                                NaN
# 36804                                                NaN
# 36805  Total - Main mode of commuting for the employe...
# 36806                                                NaN
# 36807                                                NaN
# 36808                                                NaN
# 36809                                                NaN
# 36810                                                NaN
# 36811                                                NaN
# 36812                                                NaN
# 36813  Total - Commuting duration for the employed la...
# 36814                                                NaN
# 36815                                                NaN
# 36816                                                NaN
# 36817                                                NaN
# 36818                                                NaN
# 36819  Total - Time leaving for work for the employed...
# 36820                                                NaN
# 36821                                                NaN
# 36822                                                NaN
# 36823                                                NaN
# 36824                                                NaN
# 36825                                                NaN
# 36826  Total - Eligibility for instruction in the min...
# 36827                                                NaN
# 36828                                                NaN
# 36829  Total - Eligibility and instruction in the min...
# 36830                                                NaN
# 36831                                                NaN
# 36832                                                NaN
# 36833                                                NaN
#
#                                                    Lvl-1  \
# 36784                                               None
# 36785                                            English
# 36786                                             French
# 36787                              Non-official language
# 36788                                                NaN
# 36789                                                NaN
# 36790                                 English and French
# 36791               English and non-official language(s)
# 36792                French and non-official language(s)
# 36793       English, French and non-official language(s)
# 36794                    Multiple non-official languages
# 36795                                                NaN
# 36796                                     Worked at home
# 36797                              Worked outside Canada
# 36798                         No fixed workplace address
# 36799                                Usual place of work
# 36800                                                NaN
# 36801  Commute within census subdivision (CSD) of res...
# 36802  Commute to a different census subdivision (CSD...
# 36803  Commute to a different census subdivision (CSD...
# 36804       Commute to a different province or territory
# 36805                                                NaN
# 36806                                  Car, truck or van
# 36807                                                NaN
# 36808                                                NaN
# 36809                                     Public transit
# 36810                                             Walked
# 36811                                            Bicycle
# 36812                                       Other method
# 36813                                                NaN
# 36814                               Less than 15 minutes
# 36815                                   15 to 29 minutes
# 36816                                   30 to 44 minutes
# 36817                                   45 to 59 minutes
# 36818                                60 minutes and over
# 36819                                                NaN
# 36820                       Between 5 a.m. and 5:59 a.m.
# 36821                       Between 6 a.m. and 6:59 a.m.
# 36822                       Between 7 a.m. and 7:59 a.m.
# 36823                       Between 8 a.m. and 8:59 a.m.
# 36824                      Between 9 a.m. and 11:59 a.m.
# 36825                      Between 12 p.m. and 4:59 a.m.
# 36826                                                NaN
# 36827  Children eligible for instruction in the minor...
# 36828  Children not eligible for instruction in the m...
# 36829                                                NaN
# 36830  Children eligible for instruction in the minor...
# 36831                                                NaN
# 36832                                                NaN
# 36833  Children not eligible for instruction in the m...
#
#                                                    Lvl-2 Lvl-3 Lvl-4 Lvl-5  \
# 36784                                                NaN   NaN   NaN   NaN
# 36785                                                NaN   NaN   NaN   NaN
# 36786                                                NaN   NaN   NaN   NaN
# 36787                                                NaN   NaN   NaN   NaN
# 36788                                         Indigenous   NaN   NaN   NaN
# 36789                                     Non-Indigenous   NaN   NaN   NaN
# 36790                                                NaN   NaN   NaN   NaN
# 36791                                                NaN   NaN   NaN   NaN
# 36792                                                NaN   NaN   NaN   NaN
# 36793                                                NaN   NaN   NaN   NaN
# 36794                                                NaN   NaN   NaN   NaN
# 36795                                                NaN   NaN   NaN   NaN
# 36796                                                NaN   NaN   NaN   NaN
# 36797                                                NaN   NaN   NaN   NaN
# 36798                                                NaN   NaN   NaN   NaN
# 36799                                                NaN   NaN   NaN   NaN
# 36800                                                NaN   NaN   NaN   NaN
# 36801                                                NaN   NaN   NaN   NaN
# 36802                                                NaN   NaN   NaN   NaN
# 36803                                                NaN   NaN   NaN   NaN
# 36804                                                NaN   NaN   NaN   NaN
# 36805                                                NaN   NaN   NaN   NaN
# 36806                                                NaN   NaN   NaN   NaN
# 36807                    Car, truck or van - as a driver   NaN   NaN   NaN
# 36808                 Car, truck or van - as a passenger   NaN   NaN   NaN
# 36809                                                NaN   NaN   NaN   NaN
# 36810                                                NaN   NaN   NaN   NaN
# 36811                                                NaN   NaN   NaN   NaN
# 36812                                                NaN   NaN   NaN   NaN
# 36813                                                NaN   NaN   NaN   NaN
# 36814                                                NaN   NaN   NaN   NaN
# 36815                                                NaN   NaN   NaN   NaN
# 36816                                                NaN   NaN   NaN   NaN
# 36817                                                NaN   NaN   NaN   NaN
# 36818                                                NaN   NaN   NaN   NaN
# 36819                                                NaN   NaN   NaN   NaN
# 36820                                                NaN   NaN   NaN   NaN
# 36821                                                NaN   NaN   NaN   NaN
# 36822                                                NaN   NaN   NaN   NaN
# 36823                                                NaN   NaN   NaN   NaN
# 36824                                                NaN   NaN   NaN   NaN
# 36825                                                NaN   NaN   NaN   NaN
# 36826                                                NaN   NaN   NaN   NaN
# 36827                                                NaN   NaN   NaN   NaN
# 36828                                                NaN   NaN   NaN   NaN
# 36829                                                NaN   NaN   NaN   NaN
# 36830                                                NaN   NaN   NaN   NaN
# 36831  Eligible children who have been instructed in ...   NaN   NaN   NaN
# 36832  Eligible children who have not been instructed...   NaN   NaN   NaN
# 36833                                                NaN   NaN   NaN   NaN
#
#       Lvl-6 Lvl-7 Lvl-8
# 36784   NaN   NaN   NaN
# 36785   NaN   NaN   NaN
# 36786   NaN   NaN   NaN
# 36787   NaN   NaN   NaN
# 36788   NaN   NaN   NaN
# 36789   NaN   NaN   NaN
# 36790   NaN   NaN   NaN
# 36791   NaN   NaN   NaN
# 36792   NaN   NaN   NaN
# 36793   NaN   NaN   NaN
# 36794   NaN   NaN   NaN
# 36795   NaN   NaN   NaN
# 36796   NaN   NaN   NaN
# 36797   NaN   NaN   NaN
# 36798   NaN   NaN   NaN
# 36799   NaN   NaN   NaN
# 36800   NaN   NaN   NaN
# 36801   NaN   NaN   NaN
# 36802   NaN   NaN   NaN
# 36803   NaN   NaN   NaN
# 36804   NaN   NaN   NaN
# 36805   NaN   NaN   NaN
# 36806   NaN   NaN   NaN
# 36807   NaN   NaN   NaN
# 36808   NaN   NaN   NaN
# 36809   NaN   NaN   NaN
# 36810   NaN   NaN   NaN
# 36811   NaN   NaN   NaN
# 36812   NaN   NaN   NaN
# 36813   NaN   NaN   NaN
# 36814   NaN   NaN   NaN
# 36815   NaN   NaN   NaN
# 36816   NaN   NaN   NaN
# 36817   NaN   NaN   NaN
# 36818   NaN   NaN   NaN
# 36819   NaN   NaN   NaN
# 36820   NaN   NaN   NaN
# 36821   NaN   NaN   NaN
# 36822   NaN   NaN   NaN
# 36823   NaN   NaN   NaN
# 36824   NaN   NaN   NaN
# 36825   NaN   NaN   NaN
# 36826   NaN   NaN   NaN
# 36827   NaN   NaN   NaN
# 36828   NaN   NaN   NaN
# 36829   NaN   NaN   NaN
# 36830   NaN   NaN   NaN
# 36831   NaN   NaN   NaN
# 36832   NaN   NaN   NaN
# 36833   NaN   NaN   NaN

# %%
# iterate each level column and update the NaN ones based on the hierarchy
level_val=df['Level'].unique()
for i in level_val:
    i = int(i)
    last_characteristic_name = ''
    # Iterate through the DataFrame rows
    for index, row in df_play.iterrows():
        if pd.notna(row[level_list[i]]):
            last_characteristic_name = row['CHARACTERISTIC_NAME'].strip()
        elif row['Level'] >= i:
            # Update the 'Lvl-x' column with the last_characteristic_name until the next 0 occurs
            df_play.at[index, level_list[i]] = last_characteristic_name

# %%
df_play.head(50)
# Out:
#    GEO_NAME                                CHARACTERISTIC_NAME  \
# 0    Canada                                   Population, 2021
# 1    Canada                                   Population, 2016
# 2    Canada         Population percentage change, 2016 to 2021
# 3    Canada                            Total private dwellings
# 4    Canada      Private dwellings occupied by usual residents
# 5    Canada            Population density per square kilometre
# 6    Canada                     Land area in square kilometres
# 7    Canada   Total - Age groups of the population - 100% data
# 8    Canada                                      0 to 14 years
# 9    Canada                                       0 to 4 years
# 10   Canada                                       5 to 9 years
# 11   Canada                                     10 to 14 years
# 12   Canada                                     15 to 64 years
# 13   Canada                                     15 to 19 years
# 14   Canada                                     20 to 24 years
# 15   Canada                                     25 to 29 years
# 16   Canada                                     30 to 34 years
# 17   Canada                                     35 to 39 years
# 18   Canada                                     40 to 44 years
# 19   Canada                                     45 to 49 years
# 20   Canada                                     50 to 54 years
# 21   Canada                                     55 to 59 years
# 22   Canada                                     60 to 64 years
# 23   Canada                                  65 years and over
# 24   Canada                                     65 to 69 years
# 25   Canada                                     70 to 74 years
# 26   Canada                                     75 to 79 years
# 27   Canada                                     80 to 84 years
# 28   Canada                                  85 years and over
# 29   Canada                                     85 to 89 years
# 30   Canada                                     90 to 94 years
# 31   Canada                                     95 to 99 years
# 32   Canada                                 100 years and over
# 33   Canada  Total - Distribution (%) of the population by ...
# 34   Canada                                      0 to 14 years
# 35   Canada                                     15 to 64 years
# 36   Canada                                  65 years and over
# 37   Canada                                  85 years and over
# 38   Canada                      Average age of the population
# 39   Canada                       Median age of the population
# 40   Canada  Total - Occupied private dwellings by structur...
# 41   Canada                              Single-detached house
# 42   Canada                                Semi-detached house
# 43   Canada                                          Row house
# 44   Canada                      Apartment or flat in a duplex
# 45   Canada    Apartment in a building that has fewer than ...
# 46   Canada    Apartment in a building that has five or mor...
# 47   Canada                        Other single-attached house
# 48   Canada                                   Movable dwelling
# 49   Canada  Total - Private households by household size -...
#
#     C1_COUNT_TOTAL  C2_COUNT_MEN+  C3_COUNT_WOMEN+  Level  \
# 0       36991981.0            NaN              NaN    0.0
# 1       35151728.0            NaN              NaN    0.0
# 2              5.2            NaN              NaN    0.0
# 3       16284235.0            NaN              NaN    0.0
# 4       14978941.0            NaN              NaN    0.0
# 5              4.2            NaN              NaN    0.0
# 6        8788702.8            NaN              NaN    0.0
# 7       36991980.0     18226240.0       18765740.0    0.0
# 8        6012795.0      3086510.0        2926285.0    1.0
# 9        1831195.0       938790.0         892405.0    2.0
# 10       2054900.0      1054240.0        1000655.0    2.0
# 11       2126705.0      1093480.0        1033225.0    2.0
# 12      23957760.0     11915050.0       12042710.0    1.0
# 13       2012975.0      1036730.0         976240.0    2.0
# 14       2202255.0      1138825.0        1063430.0    2.0
# 15       2421510.0      1228135.0        1193370.0    2.0
# 16       2518835.0      1252795.0        1266040.0    2.0
# 17       2511345.0      1238515.0        1272835.0    2.0
# 18       2399405.0      1175875.0        1223530.0    2.0
# 19       2304170.0      1129185.0        1174985.0    2.0
# 20       2368350.0      1161665.0        1206685.0    2.0
# 21       2647330.0      1299975.0        1347350.0    2.0
# 22       2571580.0      1253335.0        1318245.0    2.0
# 23       7021430.0      3224680.0        3796750.0    1.0
# 24       2210970.0      1065305.0        1145665.0    2.0
# 25       1847585.0       879850.0         967735.0    2.0
# 26       1260930.0       589090.0         671845.0    2.0
# 27        840545.0       370905.0         469645.0    2.0
# 28        861395.0       319540.0         541860.0    2.0
# 29        525445.0       212735.0         312705.0    3.0
# 30        258035.0        87300.0         170735.0    3.0
# 31         68380.0        17670.0          50715.0    3.0
# 32          9535.0         1830.0           7710.0    3.0
# 33           100.0          100.0            100.0    0.0
# 34            16.3           16.9             15.6    1.0
# 35            64.8           65.4             64.2    1.0
# 36            19.0           17.7             20.2    1.0
# 37             2.3            1.8              2.9    2.0
# 38            41.9           41.0             42.8    0.0
# 39            41.6           40.4             42.8    0.0
# 40      14978940.0            NaN              NaN    0.0
# 41       7872310.0            NaN              NaN    1.0
# 42        746560.0            NaN              NaN    1.0
# 43        980110.0            NaN              NaN    1.0
# 44        821490.0            NaN              NaN    1.0
# 45       2738020.0            NaN              NaN    1.0
# 46       1596155.0            NaN              NaN    1.0
# 47         34880.0            NaN              NaN    1.0
# 48        189420.0            NaN              NaN    1.0
# 49      14978940.0            NaN              NaN    0.0
#
#                                                 Lvl-0  \
# 0                                    Population, 2021
# 1                                    Population, 2016
# 2          Population percentage change, 2016 to 2021
# 3                             Total private dwellings
# 4       Private dwellings occupied by usual residents
# 5             Population density per square kilometre
# 6                      Land area in square kilometres
# 7    Total - Age groups of the population - 100% data
# 8    Total - Age groups of the population - 100% data
# 9    Total - Age groups of the population - 100% data
# 10   Total - Age groups of the population - 100% data
# 11   Total - Age groups of the population - 100% data
# 12   Total - Age groups of the population - 100% data
# 13   Total - Age groups of the population - 100% data
# 14   Total - Age groups of the population - 100% data
# 15   Total - Age groups of the population - 100% data
# 16   Total - Age groups of the population - 100% data
# 17   Total - Age groups of the population - 100% data
# 18   Total - Age groups of the population - 100% data
# 19   Total - Age groups of the population - 100% data
# 20   Total - Age groups of the population - 100% data
# 21   Total - Age groups of the population - 100% data
# 22   Total - Age groups of the population - 100% data
# 23   Total - Age groups of the population - 100% data
# 24   Total - Age groups of the population - 100% data
# 25   Total - Age groups of the population - 100% data
# 26   Total - Age groups of the population - 100% data
# 27   Total - Age groups of the population - 100% data
# 28   Total - Age groups of the population - 100% data
# 29   Total - Age groups of the population - 100% data
# 30   Total - Age groups of the population - 100% data
# 31   Total - Age groups of the population - 100% data
# 32   Total - Age groups of the population - 100% data
# 33  Total - Distribution (%) of the population by ...
# 34  Total - Distribution (%) of the population by ...
# 35  Total - Distribution (%) of the population by ...
# 36  Total - Distribution (%) of the population by ...
# 37  Total - Distribution (%) of the population by ...
# 38                      Average age of the population
# 39                       Median age of the population
# 40  Total - Occupied private dwellings by structur...
# 41  Total - Occupied private dwellings by structur...
# 42  Total - Occupied private dwellings by structur...
# 43  Total - Occupied private dwellings by structur...
# 44  Total - Occupied private dwellings by structur...
# 45  Total - Occupied private dwellings by structur...
# 46  Total - Occupied private dwellings by structur...
# 47  Total - Occupied private dwellings by structur...
# 48  Total - Occupied private dwellings by structur...
# 49  Total - Private households by household size -...
#
#                                                 Lvl-1              Lvl-2  \
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                                                 NaN                NaN
# 5                                                 NaN                NaN
# 6                                                 NaN                NaN
# 7                                                 NaN                NaN
# 8                                       0 to 14 years                NaN
# 9                                       0 to 14 years       0 to 4 years
# 10                                      0 to 14 years       5 to 9 years
# 11                                      0 to 14 years     10 to 14 years
# 12                                     15 to 64 years                NaN
# 13                                     15 to 64 years     15 to 19 years
# 14                                     15 to 64 years     20 to 24 years
# 15                                     15 to 64 years     25 to 29 years
# 16                                     15 to 64 years     30 to 34 years
# 17                                     15 to 64 years     35 to 39 years
# 18                                     15 to 64 years     40 to 44 years
# 19                                     15 to 64 years     45 to 49 years
# 20                                     15 to 64 years     50 to 54 years
# 21                                     15 to 64 years     55 to 59 years
# 22                                     15 to 64 years     60 to 64 years
# 23                                  65 years and over                NaN
# 24                                  65 years and over     65 to 69 years
# 25                                  65 years and over     70 to 74 years
# 26                                  65 years and over     75 to 79 years
# 27                                  65 years and over     80 to 84 years
# 28                                  65 years and over  85 years and over
# 29                                  65 years and over  85 years and over
# 30                                  65 years and over  85 years and over
# 31                                  65 years and over  85 years and over
# 32                                  65 years and over  85 years and over
# 33                                                NaN                NaN
# 34                                      0 to 14 years                NaN
# 35                                     15 to 64 years                NaN
# 36                                  65 years and over                NaN
# 37                                  65 years and over  85 years and over
# 38                                                NaN                NaN
# 39                                                NaN                NaN
# 40                                                NaN                NaN
# 41                              Single-detached house                NaN
# 42                                Semi-detached house                NaN
# 43                                          Row house                NaN
# 44                      Apartment or flat in a duplex                NaN
# 45  Apartment in a building that has fewer than fi...                NaN
# 46  Apartment in a building that has five or more ...                NaN
# 47                        Other single-attached house                NaN
# 48                                   Movable dwelling                NaN
# 49                                                NaN                NaN
#
#                  Lvl-3 Lvl-4 Lvl-5 Lvl-6 Lvl-7 Lvl-8
# 0                  NaN   NaN   NaN   NaN   NaN   NaN
# 1                  NaN   NaN   NaN   NaN   NaN   NaN
# 2                  NaN   NaN   NaN   NaN   NaN   NaN
# 3                  NaN   NaN   NaN   NaN   NaN   NaN
# 4                  NaN   NaN   NaN   NaN   NaN   NaN
# 5                  NaN   NaN   NaN   NaN   NaN   NaN
# 6                  NaN   NaN   NaN   NaN   NaN   NaN
# 7                  NaN   NaN   NaN   NaN   NaN   NaN
# 8                  NaN   NaN   NaN   NaN   NaN   NaN
# 9                  NaN   NaN   NaN   NaN   NaN   NaN
# 10                 NaN   NaN   NaN   NaN   NaN   NaN
# 11                 NaN   NaN   NaN   NaN   NaN   NaN
# 12                 NaN   NaN   NaN   NaN   NaN   NaN
# 13                 NaN   NaN   NaN   NaN   NaN   NaN
# 14                 NaN   NaN   NaN   NaN   NaN   NaN
# 15                 NaN   NaN   NaN   NaN   NaN   NaN
# 16                 NaN   NaN   NaN   NaN   NaN   NaN
# 17                 NaN   NaN   NaN   NaN   NaN   NaN
# 18                 NaN   NaN   NaN   NaN   NaN   NaN
# 19                 NaN   NaN   NaN   NaN   NaN   NaN
# 20                 NaN   NaN   NaN   NaN   NaN   NaN
# 21                 NaN   NaN   NaN   NaN   NaN   NaN
# 22                 NaN   NaN   NaN   NaN   NaN   NaN
# 23                 NaN   NaN   NaN   NaN   NaN   NaN
# 24                 NaN   NaN   NaN   NaN   NaN   NaN
# 25                 NaN   NaN   NaN   NaN   NaN   NaN
# 26                 NaN   NaN   NaN   NaN   NaN   NaN
# 27                 NaN   NaN   NaN   NaN   NaN   NaN
# 28                 NaN   NaN   NaN   NaN   NaN   NaN
# 29      85 to 89 years   NaN   NaN   NaN   NaN   NaN
# 30      90 to 94 years   NaN   NaN   NaN   NaN   NaN
# 31      95 to 99 years   NaN   NaN   NaN   NaN   NaN
# 32  100 years and over   NaN   NaN   NaN   NaN   NaN
# 33                 NaN   NaN   NaN   NaN   NaN   NaN
# 34                 NaN   NaN   NaN   NaN   NaN   NaN
# 35                 NaN   NaN   NaN   NaN   NaN   NaN
# 36                 NaN   NaN   NaN   NaN   NaN   NaN
# 37                 NaN   NaN   NaN   NaN   NaN   NaN
# 38                 NaN   NaN   NaN   NaN   NaN   NaN
# 39                 NaN   NaN   NaN   NaN   NaN   NaN
# 40                 NaN   NaN   NaN   NaN   NaN   NaN
# 41                 NaN   NaN   NaN   NaN   NaN   NaN
# 42                 NaN   NaN   NaN   NaN   NaN   NaN
# 43                 NaN   NaN   NaN   NaN   NaN   NaN
# 44                 NaN   NaN   NaN   NaN   NaN   NaN
# 45                 NaN   NaN   NaN   NaN   NaN   NaN
# 46                 NaN   NaN   NaN   NaN   NaN   NaN
# 47                 NaN   NaN   NaN   NaN   NaN   NaN
# 48                 NaN   NaN   NaN   NaN   NaN   NaN
# 49                 NaN   NaN   NaN   NaN   NaN   NaN

# %%
df_play.to_csv("Output/census_data_with_levels.csv", index=False)

# %% [markdown]
# # Seperator

# %%
#add the location of the file
df_census = pd.read_csv("Output/census_data_with_levels.csv", sep=',') 
df_census.head(10)
# Out:
#   GEO_NAME                               CHARACTERISTIC_NAME  C1_COUNT_TOTAL  \
# 0   Canada                                  Population, 2021      36991981.0
# 1   Canada                                  Population, 2016      35151728.0
# 2   Canada        Population percentage change, 2016 to 2021             5.2
# 3   Canada                           Total private dwellings      16284235.0
# 4   Canada     Private dwellings occupied by usual residents      14978941.0
# 5   Canada           Population density per square kilometre             4.2
# 6   Canada                    Land area in square kilometres       8788702.8
# 7   Canada  Total - Age groups of the population - 100% data      36991980.0
# 8   Canada                                     0 to 14 years       6012795.0
# 9   Canada                                      0 to 4 years       1831195.0
#
#    C2_COUNT_MEN+  C3_COUNT_WOMEN+  Level  \
# 0            NaN              NaN    0.0
# 1            NaN              NaN    0.0
# 2            NaN              NaN    0.0
# 3            NaN              NaN    0.0
# 4            NaN              NaN    0.0
# 5            NaN              NaN    0.0
# 6            NaN              NaN    0.0
# 7     18226240.0       18765740.0    0.0
# 8      3086510.0        2926285.0    1.0
# 9       938790.0         892405.0    2.0
#
#                                               Lvl-0          Lvl-1  \
# 0                                  Population, 2021            NaN
# 1                                  Population, 2016            NaN
# 2        Population percentage change, 2016 to 2021            NaN
# 3                           Total private dwellings            NaN
# 4     Private dwellings occupied by usual residents            NaN
# 5           Population density per square kilometre            NaN
# 6                    Land area in square kilometres            NaN
# 7  Total - Age groups of the population - 100% data            NaN
# 8  Total - Age groups of the population - 100% data  0 to 14 years
# 9  Total - Age groups of the population - 100% data  0 to 14 years
#
#           Lvl-2 Lvl-3 Lvl-4 Lvl-5 Lvl-6 Lvl-7 Lvl-8
# 0           NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1           NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2           NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3           NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4           NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5           NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6           NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7           NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 8           NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9  0 to 4 years   NaN   NaN   NaN   NaN   NaN   NaN

# %%
df_census['Lvl-0'].unique()
# Out:
# array(['Population, 2021', 'Population, 2016',
#        'Population percentage change, 2016 to 2021',
#        'Total private dwellings',
#        'Private dwellings occupied by usual residents',
#        'Population density per square kilometre',
#        'Land area in square kilometres',
#        'Total - Age groups of the population - 100% data',
#        'Total - Distribution (%) of the population by broad age groups - 100% data',
#        'Average age of the population', 'Median age of the population',
#        'Total - Occupied private dwellings by structural type of dwelling - 100% data',
#        'Total - Private households by household size - 100% data',
#        'Number of persons in private households',
#        'Average household size',
#        'Total - Marital status for the total population aged 15 years and over - 100% data',
#        'Total - Census families in private households by family size - 100% data',
#        'Average size of census families',
#        'Average number of children in census families with children',
#        'Total number of census families in private households - 100% data',
#        'Total - Persons in private households - 100% data',
#        'Total - Household type - 100% data',
#        'Total - Income statistics in 2020 for the population aged 15 years and over in private households - 100% data',
#        'Total - Income statistics in 2020 for the population aged 15 years and over in private households - 25% sample data',
#        'Total - Employment income statistics in 2020 for the population aged 15 years and over in private households - 25% sample data',
#        'Composition of total income in 2020 of the population aged 15 years and over in private households (%) - 25% sample data',
#        'Total - Total income groups in 2020 for the population aged 15 years and over in private households - 100% data',
#        'Total - After-tax income groups in 2020 for the population aged 15 years and over in private households - 100% data',
#        'Total - Employment income groups in 2020 for the population aged 15 years and over in private households - 100% data',
#        'Total - Income statistics in 2019 for the population aged 15 years and over in private households - 100% data',
#        'Total - Income statistics in 2019 for the population aged 15 years and over in private households - 25% sample data',
#        'Total - Employment income statistics in 2019 for the population aged 15 years and over in private households - 25% sample data',
#        'Composition of total income in 2019 of the population aged 15 years and over in private households (%) - 25% sample data',
#        'Total - Income statistics for private households - 100% data',
#        'Total - Income statistics for private households - 25% sample data',
#        'Total - Household total income groups in 2020 for private households - 100% data',
#        'Total - Household after-tax income groups in 2020 for private households - 100% data',
#        'Total - Income statistics for economic families in private households - 100% data',
#        'Total - Income statistics for couple-only economic families in private households - 100% data',
#        'Total - Income statistics for couple-with-children economic families in private households - 100% data',
#        'Total - Income statistics for one-parent economic families in private households - 100% data',
#        'Total - Income statistics for persons aged 15 years and over not in economic families in private households - 100% data',
#        'Total - Income statistics for economic families in private households - 25% sample data',
#        'Total - Income statistics for couple-only economic families in private households - 25% sample data',
#        'Total - Income statistics for couple-with-children economic families in private households - 25% sample data',
#        'Total - Income statistics for one-parent economic families in private households - 25% sample data',
#        'Total - Income statistics for persons aged 15 years and over not in economic families in private households - 25% sample data',
#        'Total - LIM low-income status in 2020 for the population in private households - 100% data',
#        'In low income based on the Low-income measure, after tax (LIM-AT)',
#        'Prevalence of low income based on the Low-income measure, after tax (LIM-AT) (%)',
#        'Total - LICO low-income status in 2020 for the population in private households to whom the low-income concept is applicable - 100% data',
#        'In low income based on the Low-income cut-offs, after tax (LICO-AT)',
#        'Prevalence of low income based on the Low-income cut-offs, after tax (LICO-AT) (%)',
#        'Total - Adjusted after-tax economic family income decile group for the population in private households - 100% data',
#        'Total - Inequality measures for the population in private households - 100% data',
#        'Total - Knowledge of official languages for the total population excluding institutional residents - 100% data',
#        'Total - First official language spoken for the total population excluding institutional residents - 100% data',
#        'Total - Mother tongue for the total population excluding institutional residents - 100% data',
#        'Total - All languages spoken at home for the total population excluding institutional residents - 100% data',
#        'Total - Language spoken most often at home for the total population excluding institutional residents - 100% data',
#        'Total - Other language(s) spoken regularly at home for the total population excluding institutional residents - 100% data',
#        'Total - Knowledge of languages for the population in private households - 25% sample data',
#        'Total - Indigenous identity for the population in private households - 25% sample data',
#        'Total - Registered or Treaty Indian status for the population in private households - 25% sample data',
#        'Total - Private households by tenure - 25% sample data',
#        'Total - Occupied private dwellings by condominium status - 25% sample data',
#        'Total - Occupied private dwellings by number of bedrooms - 25% sample data',
#        'Total - Occupied private dwellings by number of rooms - 25% sample data',
#        'Average number of rooms per dwelling',
#        'Total - Private households by number of persons per room - 25% sample data',
#        'Total - Private households by housing suitability - 25% sample data',
#        'Total - Occupied private dwellings by period of construction - 25% sample data',
#        'Total - Occupied private dwellings by dwelling condition - 25% sample data',
#        'Total - Private households by number of household maintainers - 25% sample data',
#        'Total - Private households by age of primary household maintainers - 25% sample data',
#        'Total - Owner and tenant households with household total income greater than zero, in non-farm, non-reserve private dwellings by shelter-cost-to-income ratio - 25% sample data',
#        'Total - Occupied private dwellings by housing indicators - 25% sample data',
#        'Total - Owner and tenant households with household total income greater than zero and shelter-cost-to-income ratio less than 100%, in non-farm, non-reserve private dwellings - 25% sample data',
#        'Total - Owner households in non-farm, non-reserve private dwellings - 25% sample data',
#        'Total - Tenant households in non-farm, non-reserve private dwellings - 25% sample data',
#        'Total - Households living in a dwelling provided by the local government, First Nation or Indian band in non-farm private dwellings - 25% sample data',
#        'Total - Indigenous ancestry for the population in private households - 25% sample data',
#        'Total - Citizenship for the population in private households - 25% sample data',
#        'Total - Immigrant status and period of immigration for the population in private households - 25% sample data',
#        'Total - Age at immigration for the immigrant population in private households - 25% sample data',
#        'Total - Place of birth for the immigrant population in private households - 25% sample data',
#        'Total - Place of birth for the recent immigrant population in private households - 25% sample data',
#        'Total - Generation status for the population in private households - 25% sample data',
#        'Total - Admission category and applicant type for the immigrant population in private households who were admitted between 1980 and 2021 - 25% sample data',
#        'Total - Pre-admission experience for the immigrant population in private households who were admitted between 1980 and 2021 - 25% sample data',
#        'Total - Visible minority for the population in private households - 25% sample data',
#        'Total - Ethnic or cultural origin for the population in private households - 25% sample data',
#        'Total - Religion for the population in private households - 25% sample data',
#        'Total - Mobility status 1 year ago - 25% sample data',
#        'Total - Mobility status 5 years ago - 25% sample data',
#        'Total - Secondary (high) school diploma or equivalency certificate for the population aged 15 years and over in private households - 25% sample data',
#        'Total - Secondary (high) school diploma or equivalency certificate for the population aged 25 to 64 years in private households - 25% sample data',
#        'Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data',
#        'Total - Highest certificate, diploma or degree for the population aged 25 to 64 years in private households - 25% sample data',
#        'Total - Major field of study - Classification of Instructional Programs (CIP) 2021 for the population aged 15 years and over in private households - 25% sample data',
#        'Total - Major field of study - Classification of Instructional Programs (CIP) 2021 for the population aged 25 to 64 years in private households - 25% sample data',
#        'Total - Location of study compared with province or territory of residence for the population aged 25 to 64 years in private households - 25% sample data',
#        'Total - Population aged 15 years and over by labour force status - 25% sample data',
#        'Participation rate', 'Employment rate', 'Unemployment rate',
#        'Total - Population aged 15 years and over by work activity during the reference year - 25% sample data',
#        'Total - Labour force aged 15 years and over by class of worker including job permanency - 25% sample data',
#        'Total - Labour force aged 15 years and over by occupation - Broad category - National Occupational Classification (NOC) 2021 - 25% sample data',
#        'Total - Labour force aged 15 years and over by industry - Sectors - North American Industry Classification System (NAICS) 2017 - 25% sample data',
#        'Total - All languages used at work for the population in private households aged 15 years and over who worked since January 1, 2020 - 25% sample data',
#        'Total - Language used most often at work for the population aged 15 years and over who worked since January 1, 2020, in private households, 2021 Census - 25% sample data',
#        'Total - Other language(s) used regularly at work for the population in private households aged 15 years and over who worked since January 1, 2020 - 25% sample data',
#        'Total - Place of work status for the employed labour force aged 15 years and over - 25% sample data',
#        'Total - Commuting destination for the employed labour force aged 15 years and over with a usual place of work - 25% sample data',
#        'Total - Main mode of commuting for the employed labour force aged 15 years and over with a usual place of work or no fixed workplace address - 25% sample data',
#        'Total - Commuting duration for the employed labour force aged 15 years and over with a usual place of work or no fixed workplace address - 25% sample data',
#        'Total - Time leaving for work for the employed labour force aged 15 years and over with a usual place of work or no fixed workplace address - 25% sample data',
#        'Total - Eligibility for instruction in the minority official language for the population in private households born in 2003 or later - 100% data',
#        'Total - Eligibility and instruction in the minority official language, for the population in private households born between 2003 and 2015 (inclusive) - 100% data'],
#       dtype=object)

# %%
# List of values to filter the 'Lvl-0' column
filter_values = ['Total - Age groups of the population - 100% data',
                 'Total - Total income groups in 2020 for the population aged 15 years and over in private households - 100% data',
                 'Total - Occupied private dwellings by structural type of dwelling - 100% data',
                 'Total - Marital status for the total population aged 15 years and over - 100% data']

# Filtering the DataFrame based on the 'Lvl-0' column
features_df = df_census[df_census['Lvl-0'].isin(filter_values)]

# Display the first few rows of the filtered DataFrame
features_df.head()

features_df.to_csv('filtered_data.csv')

# %%
pivot_features_df = features_df.pivot_table(index='GEO_NAME', columns=['Lvl-2'], values='C1_COUNT_TOTAL')
pivot_features_df.to_csv('Output/pivot_features.csv', sep =",")

# %%
education_level = df_census[df_census['Lvl-0']=='Total - Secondary (high) school diploma or equivalency certificate for the population aged 15 years and over in private households - 25% sample data']
pivot_education = education_level.pivot_table(index = 'GEO_NAME', columns='Lvl-1', values='C1_COUNT_TOTAL')
pivot_education.head(14)
# Out:
# Lvl-1                      No high school diploma or equivalency certificate  \
# GEO_NAME
# Alberta                                                             595665.0
# British Columbia                                                    643330.0
# Canada                                                             5474175.0
# Manitoba                                                            220975.0
# New Brunswick                                                       135565.0
# Newfoundland and Labrador                                            96375.0
# Northwest Territories                                                 9595.0
# Nova Scotia                                                         157255.0
# Nunavut                                                              14030.0
# Ontario                                                            1969920.0
# Prince Edward Island                                                 22245.0
# Quebec                                                             1426055.0
# Saskatchewan                                                        177330.0
# Yukon                                                                 5840.0
#
# Lvl-1                      With high school diploma or equivalency certificate
# GEO_NAME
# Alberta                                                            2779465.0
# British Columbia                                                   3557095.0
# Canada                                                            24861745.0
# Manitoba                                                            837440.0
# New Brunswick                                                       512680.0
# Newfoundland and Labrador                                           337580.0
# Northwest Territories                                                22320.0
# Nova Scotia                                                         662060.0
# Nunavut                                                              10510.0
# Ontario                                                            9812905.0
# Prince Edward Island                                                104655.0
# Quebec                                                             5492670.0
# Saskatchewan                                                        705430.0
# Yukon                                                                26940.0

# %%
result = pd.merge(pivot_features_df, pivot_education,how = "inner", on = "GEO_NAME")
result.head()
result.to_csv('./Output/features_of_interest.csv', sep =",")

# %% [markdown]
# # Separate Pivots for Features of Interest

# %%
age_group = df_census[df_census['Lvl-0'] == 'Total - Age groups of the population - 100% data']
pivot_age_group_province = age_group.pivot_table(index='GEO_NAME', columns='Lvl-2', values='C1_COUNT_TOTAL')
pivot_age_group_province.to_csv('./Output/pivot_age_group_province.csv', sep =",")

# %%
total_income_groups = df_census[df_census['Lvl-0'] == 'Total - Total income groups in 2020 for the population aged 15 years and over in private households - 100% data']
pivot_total_income_groups = total_income_groups.pivot_table(index='GEO_NAME', columns='Lvl-2', values='C1_COUNT_TOTAL', aggfunc = 'sum')
pivot_total_income_groups.to_csv('./Output/pivot_total_income_groups.csv', sep =",")

# %%
total_languages_spoken = df_census[df_census['Lvl-0'] == 'Total - All languages spoken at home for the total population excluding institutional residents - 100% data']
pivot_total_languages_spoken = total_languages_spoken.pivot_table(index='GEO_NAME', columns='Lvl-1', values='C1_COUNT_TOTAL')
pivot_total_languages_spoken.to_csv('./Output/pivot_total_languages_spoken.csv',sep =",")

# %%
population_density = df_census[df_census['Lvl-0'] == 'Population density per square kilometre']
pivot_population_density = population_density.pivot_table(index='GEO_NAME', columns='Lvl-0', values='C1_COUNT_TOTAL')
pivot_population_density.head(13)
# Out:
# Lvl-0                      Population density per square kilometre
# GEO_NAME
# Alberta                                                        6.7
# British Columbia                                               5.4
# Canada                                                         4.2
# Manitoba                                                       2.5
# New Brunswick                                                 10.9
# Newfoundland and Labrador                                      1.4
# Northwest Territories                                          0.0
# Nova Scotia                                                   18.4
# Nunavut                                                        0.0
# Ontario                                                       15.9
# Prince Edward Island                                          27.2
# Quebec                                                         6.5
# Saskatchewan                                                   2.0

# %%
total_private_dwelling_types = df_census[df_census['Lvl-0']=='Total - Occupied private dwellings by structural type of dwelling - 100% data']
pivot_total_private_dwelling_types = total_private_dwelling_types.pivot_table(index='GEO_NAME', columns='Lvl-1', values='C1_COUNT_TOTAL')
pivot_total_private_dwelling_types.to_csv('./Output/pivot_total_private_dwelling_types.csv',sep =",")

# %%
total_marital_status = df_census[df_census['Lvl-0']=='Total - Marital status for the total population aged 15 years and over - 100% data']
pivot_marital_status = total_marital_status.pivot_table(index='GEO_NAME', columns='Lvl-2', values='C1_COUNT_TOTAL', aggfunc = "sum")
pivot_marital_status.head()
# Out:
# Lvl-2             Living common-law     Married  \
# GEO_NAME
# Alberta                    661305.0   1703285.0
# British Columbia           855935.0   2036165.0
# Canada                    7800750.0  13725625.0
# Manitoba                   201570.0    515480.0
# New Brunswick              173795.0    298905.0
#
# Lvl-2             Not married and not living common law - Divorced  \
# GEO_NAME
# Alberta                                                   214460.0
# British Columbia                                          283035.0
# Canada                                                   1921880.0
# Manitoba                                                   57440.0
# New Brunswick                                              38865.0
#
# Lvl-2             Not married and not living common law - Never married  \
# GEO_NAME
# Alberta                                                    969780.0
# British Columbia                                          1202625.0
# Canada                                                    9025865.0
# Manitoba                                                   330855.0
# New Brunswick                                              174335.0
#
# Lvl-2             Not married and not living common law - Separated  \
# GEO_NAME
# Alberta                                                     83350.0
# British Columbia                                           110710.0
# Canada                                                     741135.0
# Manitoba                                                    24470.0
# New Brunswick                                               21995.0
#
# Lvl-2             Not married and not living common law - Widowed
# GEO_NAME
# Alberta                                                  151455.0
# British Columbia                                         223475.0
# Canada                                                  1664295.0
# Manitoba                                                  60190.0
# New Brunswick                                             43480.0
